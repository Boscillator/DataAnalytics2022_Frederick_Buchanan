# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
ndvi = rasterio.open('netcdf:../data/raw/ndvi/2020.100.nc:NDVI')

# %%
ndvi.bounds
# Out:
# BoundingBox(left=-180.00000610436345, bottom=-89.99999084324266, right=180.00000610436345, top=89.99999847263719)

# %%
img = ndvi.read(1)
plt.imshow(img)
